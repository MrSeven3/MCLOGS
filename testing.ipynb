# %%
import re
NEOFORGE_JAVA_VERSION_LINE_DETECT_REGEX = r".*\[main\/INFO\].*: ModLauncher.+ java version "

if re.match(NEOFORGE_JAVA_VERSION_LINE_DETECT_REGEX,"[22Dec2025 16:14:56.788] [main/INFO] [cpw.mods.modlauncher.Launcher/MODLAUNCHER]: ModLauncher 11.0.5+main.901c6ea8 starting: java version 21.0.7 by Microsoft; OS Windows 11 arch amd64 version 10.0"):
    print("Yes")
# Out:
# Yes
